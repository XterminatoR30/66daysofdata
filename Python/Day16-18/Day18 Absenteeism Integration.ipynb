# %%
from Day18_Absenteeism_Class_Module import *

# %%
data=pd.read_csv('Absenteeism_new_data.csv')
data
# Out:
#     ID  Reason for Absence        Date  Transportation Expense  \
# 0   22                  27  01/06/2018                     179
# 1   10                   7  04/06/2018                     361
# 2   14                  23  06/06/2018                     155
# 3   17                  25  08/06/2018                     179
# 4   14                  10  08/06/2018                     155
# 5   28                  11  11/06/2018                     225
# 6   16                   7  13/06/2018                     118
# 7   22                  27  13/06/2018                     179
# 8   34                  26  15/06/2018                     118
# 9   34                  10  20/06/2018                     118
# 10  23                  22  21/06/2018                     378
# 11  36                  19  21/06/2018                     118
# 12  12                  19  22/06/2018                     233
# 13  22                  27  22/06/2018                     179
# ...

# %%
data.shape
# Out:
# (40, 11)

# %%
model=absenteeism_model('absenteeism_model','absenteeism_scaler')

# %%
model.load_and_clean_data('Absenteeism_new_data.csv')

# %%
model.predicted_outputs()
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Month  Transportation Expense  \
# 0          0       0.0         0         1      6                     179
# 1          1       0.0         0         0      6                     361
# 2          0       0.0         0         1      6                     155
# 3          0       0.0         0         1      6                     179
# 4          1       0.0         0         0      6                     155
# 5          1       0.0         0         0      6                     225
# 6          1       0.0         0         0      6                     118
# 7          0       0.0         0         1      6                     179
# 8          0       0.0         0         1      6                     118
# 9          1       0.0         0         0      6                     118
# 10         0       0.0         0         1      6                     378
# 11         0       0.0         1         0      6                     118
# ...

# %%
model.predicted_outputs().to_csv('Absenteeism_predictions.csv',index=False)

# %%
new_data=pd.read_csv('Absenteeism_predictions.csv')
new_data
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Month  Transportation Expense  \
# 0          0       0.0         0         1      6                     179
# 1          1       0.0         0         0      6                     361
# 2          0       0.0         0         1      6                     155
# 3          0       0.0         0         1      6                     179
# 4          1       0.0         0         0      6                     155
# 5          1       0.0         0         0      6                     225
# 6          1       0.0         0         0      6                     118
# 7          0       0.0         0         1      6                     179
# 8          0       0.0         0         1      6                     118
# 9          1       0.0         0         0      6                     118
# 10         0       0.0         0         1      6                     378
# 11         0       0.0         1         0      6                     118
# ...

# %%
import matplotlib.pyplot as plt
x=
