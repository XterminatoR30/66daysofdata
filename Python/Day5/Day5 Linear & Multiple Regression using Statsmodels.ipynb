# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn
import scipy

# %%
data=pd.read_csv('real_estate_price_size.csv')
data
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %%
data.describe()
# Out:
#                price         size
# count     100.000000   100.000000
# mean   292289.470160   853.024200
# std     77051.727525   297.941951
# min    154282.128000   479.750000
# 25%    234280.148000   643.330000
# 50%    280590.716000   696.405000
# 75%    335723.696000  1029.322500
# max    500681.128000  1842.510000

# %%
import statsmodels.api as sm
from statsmodels.api import add_constant
import seaborn as sns
sns.set()

# %%
x1=data['size']
y=data['price']
plt.scatter(x1,y,c='blue')
plt.xlabel('Size',fontsize=20)
plt.ylabel('Price',fontsize=20)
plt.show()

# %%
x=sm.add_constant(x1)
result=sm.OLS(y,x).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     285.9
# Date:                Tue, 21 Sep 2021   Prob (F-statistic):           8.13e-31
# Time:                        18:50:40   Log-Likelihood:                -1198.3
# No. Observations:                 100   AIC:                             2401.
# Df Residuals:                      98   BIC:                             2406.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.019e+05   1.19e+04      8.550      0.000    7.83e+04    1.26e+05
# ...

# %%
plt.scatter(x1,y)
yhat=223.1787*x1+101900
fig=plt.plot(x1,yhat,lw=4,c='red')
plt.xlabel('Size',fontsize=20)
plt.ylabel('Price',fontsize=20)
plt.show()

# %%
data2=pd.read_csv('1.02.+Multiple+linear+regression.csv')
data2
# Out:
#      SAT   GPA  Rand 1,2,3
# 0   1714  2.40           1
# 1   1664  2.52           3
# 2   1760  2.54           3
# 3   1685  2.74           3
# 4   1693  2.83           2
# ..   ...   ...         ...
# 79  1936  3.71           3
# 80  1810  3.71           1
# 81  1987  3.73           3
# 82  1962  3.76           1
# 83  2050  3.81           2
#
# [84 rows x 3 columns]

# %%
data2.describe()
# Out:
#                SAT        GPA  Rand 1,2,3
# count    84.000000  84.000000   84.000000
# mean   1845.273810   3.330238    2.059524
# std     104.530661   0.271617    0.855192
# min    1634.000000   2.400000    1.000000
# 25%    1772.000000   3.190000    1.000000
# 50%    1846.000000   3.380000    2.000000
# 75%    1934.000000   3.502500    3.000000
# max    2050.000000   3.810000    3.000000

# %%
y=data2['GPA']
x1=data2[['SAT','Rand 1,2,3']]
x=sm.add_constant(x1)
result=sm.OLS(y,x).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.407
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     27.76
# Date:                Wed, 22 Sep 2021   Prob (F-statistic):           6.58e-10
# Time:                        11:51:45   Log-Likelihood:                 12.720
# No. Observations:                  84   AIC:                            -19.44
# Df Residuals:                      81   BIC:                            -12.15
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2960      0.417      0.710      0.480      -0.533       1.125
# ...

# %%
data3=pd.read_csv('real_estate_price_size_year.csv')
data3
# Out:
#          price     size  year
# 0   234314.144   643.09  2015
# 1   228581.528   656.22  2009
# 2   281626.336   487.29  2018
# 3   401255.608  1504.75  2015
# 4   458674.256  1275.46  2009
# ..         ...      ...   ...
# 95  252460.400   549.80  2009
# 96  310522.592  1037.44  2009
# 97  383635.568  1504.75  2006
# 98  225145.248   648.29  2015
# 99  274922.856   705.29  2006
#
# [100 rows x 3 columns]

# %%
data3.describe()
# Out:
#                price         size         year
# count     100.000000   100.000000   100.000000
# mean   292289.470160   853.024200  2012.600000
# std     77051.727525   297.941951     4.729021
# min    154282.128000   479.750000  2006.000000
# 25%    234280.148000   643.330000  2009.000000
# 50%    280590.716000   696.405000  2015.000000
# 75%    335723.696000  1029.322500  2018.000000
# max    500681.128000  1842.510000  2018.000000

# %%
y2=data3['price']
x2=data3[['size','year']]
x3=sm.add_constant(x2)
result2=sm.OLS(y2,x3).fit()
result2.summary()
#FINAL EQUATION
#yhat=227.7009*x1+2916.7853*x2-5772000

#CONCLUSION
#Both R Squared and Adj R Squared has very high value, therefore the model fits the data very well
#With the addition of new variable YEAR, it increases the Adj R squared value, therefore it's a significant variable for this model
#P value of all three variables are 0, which is <0.005, it further enhance the conclusion that these 3 values are very significant to each other
#Based on the DURBIN WATSON test, the score is 2.25 which is close to the value of 2. This means that the model has no autocorrelation assumption
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.776
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     168.5
# Date:                Wed, 22 Sep 2021   Prob (F-statistic):           2.77e-32
# Time:                        12:08:21   Log-Likelihood:                -1191.7
# No. Observations:                 100   AIC:                             2389.
# Df Residuals:                      97   BIC:                             2397.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.772e+06   1.58e+06     -3.647      0.000   -8.91e+06   -2.63e+06
# ...

# %%
plt.scatter(data3['size'],y2)
yhat=227.7009*data3['size']+2916.7853*data3['year']-5772000
fig=plt.plot(data3['size'],yhat,lw=2,c='green')
plt.xlabel('Size',fontsize=20)
plt.ylabel('Price',fontsize=20)
plt.show()

# %%
#ASSUMPTIONS
#1.Linearity
#2.No Endogeneity
#3.Normality and Homoscedacity
#4.No Autocorrelation
#5.No Mutlicollinearity
data4=pd.read_csv('1.03.+Dummies.csv')
data4
# Out:
#      SAT   GPA Attendance
# 0   1714  2.40         No
# 1   1664  2.52         No
# 2   1760  2.54         No
# 3   1685  2.74         No
# 4   1693  2.83         No
# ..   ...   ...        ...
# 79  1936  3.71        Yes
# 80  1810  3.71        Yes
# 81  1987  3.73         No
# 82  1962  3.76        Yes
# 83  2050  3.81        Yes
#
# [84 rows x 3 columns]

# %%
#PANDAS
data5=data4.copy()
data5['Attendance']=data5['Attendance'].map({'Yes':1,'No':0})

# %%
data5
# Out:
#      SAT   GPA  Attendance
# 0   1714  2.40           0
# 1   1664  2.52           0
# 2   1760  2.54           0
# 3   1685  2.74           0
# 4   1693  2.83           0
# ..   ...   ...         ...
# 79  1936  3.71           1
# 80  1810  3.71           1
# 81  1987  3.73           0
# 82  1962  3.76           1
# 83  2050  3.81           1
#
# [84 rows x 3 columns]

# %%
data5.describe()
# Out:
#                SAT        GPA  Attendance
# count    84.000000  84.000000   84.000000
# mean   1845.273810   3.330238    0.464286
# std     104.530661   0.271617    0.501718
# min    1634.000000   2.400000    0.000000
# 25%    1772.000000   3.190000    0.000000
# 50%    1846.000000   3.380000    0.000000
# 75%    1934.000000   3.502500    1.000000
# max    2050.000000   3.810000    1.000000

# %%
y4=data5['GPA']
x4=data5[['SAT','Attendance']]
x5=sm.add_constant(x4)
result4=sm.OLS(y4,x5).fit()
result4.summary()
#Yhat Equation
#yhat=0.0014*x1+0.2226*x2+0.6439

#Conclusion
#Based on the OLS model summary, it can be said that the model has a good fit with the data. As both R squared and Adj R squared value increases to >0.5
#Overall model also seems significant as F-Stats value is above 50
#All three variables are highly correlated as P value for SAT and attendance is below <0.005 threshold
#Since durbin watson value is still above 1, it can be said that the model has no autocorrelation observed
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     52.70
# Date:                Wed, 22 Sep 2021   Prob (F-statistic):           2.19e-15
# Time:                        15:04:13   Log-Likelihood:                 25.798
# No. Observations:                  84   AIC:                            -45.60
# Df Residuals:                      81   BIC:                            -38.30
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6439      0.358      1.797      0.076      -0.069       1.357
# ...

# %%
plt.scatter(data4['SAT'],y4)
yhat_no=0.0014*data4['SAT']+0.6439
yhat_yes=0.0014*data4['SAT']+0.8665
fig=plt.plot(data4['SAT'],yhat_no,lw=2,c='red')
fig=plt.plot(data4['SAT'],yhat_yes,lw=2,c='green')
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.show()

# %%
plt.scatter(data4['SAT'],data4['GPA'])
yhat_no=0.0014*data4['SAT']+0.6439
yhat_yes=0.0014*data4['SAT']+0.8665
yhat=0.0017*data4['SAT']+0.275
fig=plt.plot(data4['SAT'],yhat_no,lw=2,c='red')
fig=plt.plot(data4['SAT'],yhat_yes,lw=2,c='green')
fig=plt.plot(data4['SAT'],yhat,lw=2,c='blue')
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.show()

# %%
data6=pd.read_csv('real_estate_price_size_year_view.csv')
data6
# Out:
#          price     size  year         view
# 0   234314.144   643.09  2015  No sea view
# 1   228581.528   656.22  2009  No sea view
# 2   281626.336   487.29  2018     Sea view
# 3   401255.608  1504.75  2015  No sea view
# 4   458674.256  1275.46  2009     Sea view
# ..         ...      ...   ...          ...
# 95  252460.400   549.80  2009     Sea view
# 96  310522.592  1037.44  2009  No sea view
# 97  383635.568  1504.75  2006  No sea view
# 98  225145.248   648.29  2015  No sea view
# 99  274922.856   705.29  2006     Sea view
#
# [100 rows x 4 columns]

# %%
data7=data6.copy()
data7['view']=data7['view'].map({'No sea view':0,'Sea view':1})
data7
# Out:
#          price     size  year  view
# 0   234314.144   643.09  2015     0
# 1   228581.528   656.22  2009     0
# 2   281626.336   487.29  2018     1
# 3   401255.608  1504.75  2015     0
# 4   458674.256  1275.46  2009     1
# ..         ...      ...   ...   ...
# 95  252460.400   549.80  2009     1
# 96  310522.592  1037.44  2009     0
# 97  383635.568  1504.75  2006     0
# 98  225145.248   648.29  2015     0
# 99  274922.856   705.29  2006     1
#
# [100 rows x 4 columns]

# %%
data7.describe()
# Out:
#                price         size         year        view
# count     100.000000   100.000000   100.000000  100.000000
# mean   292289.470160   853.024200  2012.600000    0.490000
# std     77051.727525   297.941951     4.729021    0.502418
# min    154282.128000   479.750000  2006.000000    0.000000
# 25%    234280.148000   643.330000  2009.000000    0.000000
# 50%    280590.716000   696.405000  2015.000000    0.000000
# 75%    335723.696000  1029.322500  2018.000000    1.000000
# max    500681.128000  1842.510000  2018.000000    1.000000

# %%
y6=data7['price']
x6=data7[['size','year','view']]
x7=sm.add_constant(x6)
result=sm.OLS(y6,x7).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     335.2
# Date:                Wed, 22 Sep 2021   Prob (F-statistic):           1.02e-50
# Time:                        15:45:38   Log-Likelihood:                -1144.6
# No. Observations:                 100   AIC:                             2297.
# Df Residuals:                      96   BIC:                             2308.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.398e+06   9.94e+05     -5.431      0.000   -7.37e+06   -3.43e+06
# ...

# %%
plt.scatter(data7['size'],y6)
yhat1=223.0316*data7['size']+2718.9489*data7['year']+56730*data7['view']-5398000
fig=plt.plot(data7['size'],yhat1,lw=2,c='green')
plt.xlabel('Size',fontsize=20)
plt.ylabel('Price',fontsize=20)
plt.show()

# %% [markdown]
# # REGRESSION PREDICTION

# %%
x5
# Out:
#     const   SAT  Attendance
# 0     1.0  1714           0
# 1     1.0  1664           0
# 2     1.0  1760           0
# 3     1.0  1685           0
# 4     1.0  1693           0
# ..    ...   ...         ...
# 79    1.0  1936           1
# 80    1.0  1810           1
# 81    1.0  1987           0
# 82    1.0  1962           1
# 83    1.0  2050           1
#
# [84 rows x 3 columns]

# %%
new_data=pd.DataFrame({'const':1,'SAT':[1700,1670],'Attendance':[0,1]})
new_data=new_data[['const','SAT','Attendance']]
new_data
# Out:
#    const   SAT  Attendance
# 0      1  1700           0
# 1      1  1670           1

# %%
predictions=result4.predict(new_data)
predictions
# Out:
# 0    3.023513
# 1    3.204163
# dtype: float64

# %%
predictionsdf=pd.DataFrame({'Predictions':predictions})
joined= new_data.join(predictionsdf)
joined.rename(index={0:'Bill',1:'Jack'})
# Out:
#       const   SAT  Attendance  Predictions
# Bill      1  1700           0     3.023513
# Jack      1  1670           1     3.204163
